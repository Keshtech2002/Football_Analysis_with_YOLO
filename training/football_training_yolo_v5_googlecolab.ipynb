# %%
from google.colab import userdata
ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')

# %%
# !pip install ultralytics
# !pip install roboflow

# %%
# from dotenv import load_dotenv
# import os


# load_dotenv()
# ROBOFLOW_API_KEY = os.environ.get("ROBOFLOW_API_KEY")
# assert ROBOFLOW_API_KEY is not None, "API key not found!"

# %%
# from roboflow import Roboflow
# rf = Roboflow(api_key=ROBOFLOW_API_KEY)
# project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
# version = project.version(1)
# dataset = version.download("yolov5")

# %%
import os
from roboflow import Roboflow

# ROBOFLOW_API_KEY = os.environ.get("ROBOFLOW_API_KEY")

# assert ROBOFLOW_API_KEY is not None, "ROBOFLOW_API_KEY not found in Colab Secrets"

rf = Roboflow(api_key=ROBOFLOW_API_KEY)
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 2822.33it/s]

# %%
import shutil # move and copy files and folders

shutil.move('football-players-detection-1/train', 'football-players-detection-1/football-players-detection-1/train')
shutil.move('football-players-detection-1/test', 'football-players-detection-1/football-players-detection-1/test')
shutil.move('football-players-detection-1/valid', 'football-players-detection-1/football-players-detection-1/valid')
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# ### Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r yolov5_train.zip runs/detect/train
# Out:
#   adding: runs/detect/train/ (stored 0%)
#   adding: runs/detect/train/train_batch3511.jpg (deflated 9%)
#   adding: runs/detect/train/val_batch0_pred.jpg (deflated 4%)
#   adding: runs/detect/train/train_batch3512.jpg (deflated 10%)
#   adding: runs/detect/train/train_batch1.jpg (deflated 4%)
#   adding: runs/detect/train/train_batch3510.jpg (deflated 10%)
#   adding: runs/detect/train/results.png (deflated 8%)
#   adding: runs/detect/train/val_batch0_labels.jpg (deflated 5%)
#   adding: runs/detect/train/BoxF1_curve.png (deflated 10%)
#   adding: runs/detect/train/weights/ (stored 0%)
#   adding: runs/detect/train/weights/best.pt (deflated 8%)
#   adding: runs/detect/train/weights/last.pt (deflated 8%)
#   adding: runs/detect/train/train_batch0.jpg (deflated 5%)
#   adding: runs/detect/train/confusion_matrix_normalized.png (deflated 25%)
#   adding: runs/detect/train/BoxP_curve.png (deflated 15%)
#   adding: runs/detect/train/results.csv (deflated 63%)
# ...

# %%
from google.colab import files
files.download("yolov5_train.zip")
