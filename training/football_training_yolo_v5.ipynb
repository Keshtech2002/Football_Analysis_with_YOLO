# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# Requirement already satisfied: ultralytics in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (8.3.228)
# Requirement already satisfied: numpy>=1.23.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from ultralytics) (3.10.7)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: psutil in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from ultralytics) (7.1.3)
# Requirement already satisfied: polars in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: networkx in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.9.86)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from polars->ultralytics) (1.35.2)
# Collecting roboflow
#   Downloading roboflow-1.2.11-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from roboflow) (2025.11.12)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from roboflow) (3.10.7)
# Requirement already satisfied: numpy>=1.18.5 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from roboflow) (2.2.6)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from roboflow) (12.0.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.1.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: requests in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from roboflow) (2.5.0)
# Collecting tqdm>=4.41.0 (from roboflow)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from roboflow) (6.0.2)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from matplotlib->roboflow) (4.60.1)
# Requirement already satisfied: packaging>=20.0 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=3 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from matplotlib->roboflow) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/keshtech/miniconda3/envs/yolo_gpu/lib/python3.11/site-packages (from requests->roboflow) (3.4.4)
# Downloading roboflow-1.2.11-py3-none-any.whl (89 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/49.9 MB ? eta -:--:--0m
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (524 kB/49.9 MB, attempt 1)
# Resuming download opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (524 kB/49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/49.9 MB ? eta -:--:--0m
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (524 kB/49.9 MB, attempt 2)
# Resuming download opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (524 kB/49.9 MB)
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/49.9 MB 384.1 kB/s eta 0:01:38:40
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (12.6 MB/49.9 MB, attempt 3)
# Resuming download opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.6 MB/49.9 MB)
#    ━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━ 20.7/49.9 MB 907.5 kB/s eta 0:00:33
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (20.7 MB/49.9 MB, attempt 4)
# Resuming download opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.7 MB/49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 698.9 kB/s  0:01:06 eta 0:00:010:00:03
# Downloading pi_heif-1.1.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.3 MB/s  0:00:01m 1.5 MB/s eta 0:00:01
# Downloading pillow_avif_plugin-1.5.2-cp311-cp311-manylinux_2_28_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 699.8 kB/s  0:00:06690.6 kB/s eta 0:00:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, tqdm, python-dotenv, pi-heif, opencv-python-headless, idna, requests-toolbelt, roboflow
#   Attempting uninstall: idna━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━ 5/9 [opencv-python-headless]
#     Found existing installation: idna 3.11m╺━━━━━━━━━━━━━━━━━ 5/9 [opencv-python-headless]
#     Uninstalling idna-3.11:━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━ 5/9 [opencv-python-headless]
#       Successfully uninstalled idna-3.11╺━━━━━━━━━━━━━━━━━ 5/9 [opencv-python-headless]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [roboflow]━━━━━━━━━ 6/9 [idna]adless]
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.1.1 pillow-avif-plugin-1.5.2 python-dotenv-1.2.1 requests-toolbelt-1.0.0 roboflow-1.2.11 tqdm-4.67.1

# %%
from dotenv import load_dotenv
import os


load_dotenv()
ROBOFLOW_API_KEY = os.getenv("ROBOFLOW_API_KEY")

# %%
from roboflow import Roboflow
rf = Roboflow(api_key=ROBOFLOW_API_KEY)
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolov5pytorch:: 100%|██████████| 148663/148663 [03:38<00:00, 681.51it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 1719.46it/s]

# %%
import shutil # move and copy files and folders

shutil.move('football-players-detection-1/train', 'football-players-detection-1/football-players-detection-1/train')
shutil.move('football-players-detection-1/test', 'football-players-detection-1/football-players-detection-1/test')
shutil.move('football-players-detection-1/valid', 'football-players-detection-1/football-players-detection-1/valid')
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# ### Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
